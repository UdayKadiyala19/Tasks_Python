# %% [markdown]
# ##### step 1. load the iris.csv dataset.

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\udayk\Downloads\1569614-1567135-1541251-Pandas_assignment\Pandas_assignment\Pandas_day_1\Iris.csv")

# %%
df.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# ##### 1. Write a Pandas program to get the data types of the given csv data (iris.csv ) fields

# %%
### code here
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# ##### 2. Write a Pandas program to find the sum, mean, max, min value of 'SepalLengthCm' column of dataframe

# %%
### code here
df["SepalLengthCm"].agg(['mean','sum',"max","min"])
# Out:
# mean      5.843333
# sum     876.500000
# max       7.900000
# min       4.300000
# Name: SepalLengthCm, dtype: float64

# %% [markdown]
# ##### 3. Write a Pandas program to import iris data and skipping first twenty rows into a Pandas dataframe.

# %%
### code here
df1= df.iloc[20:]
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [130 rows x 6 columns]

# %% [markdown]
# ##### 4. Write a Pandas program to display the last ten rows.

# %%
### code here
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ##### 5. Write a Pandas program to create a subtotal of "PetalLengthCm" against Species from the dataframe.

# %%
### code here
subtotal= df.groupby("Species")["PetalLengthCm"].sum().reset_index()
subtotal
# Out:
#            Species  PetalLengthCm
# 0      Iris-setosa           73.2
# 1  Iris-versicolor          213.0
# 2   Iris-virginica          277.6

# %% [markdown]
# ###### 6. Write a Pandas program to find details where "PetalLengthCm" > 2.

# %%
### code here
df[df["PetalLengthCm"]>2]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica
#
# [100 rows x 6 columns]

# %% [markdown]
# ###### 7. Write a Pandas program find all records that include two specific Species.

# %%
### code here
df[(df["Species"]== "Iris-versicolor") | (df["Species"]=="Iris-virginica")]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica
#
# [100 rows x 6 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to sort the records by the SepalLengthCm column.

# %%
### code here
df["SepalLengthCm"].sort_values()
# Out:
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
#       ...
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %% [markdown]
# ##### 9. Write a Pandas program to insert a column in the sixth position of dataframe and fill it with NaN values.

# %%
### code here

list1=[]
for i in range(150):
    list1.append(np.nan)
list1

df["NaN"]=list1
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  NaN
# 0       Iris-setosa  NaN
# 1       Iris-setosa  NaN
# 2       Iris-setosa  NaN
# 3       Iris-setosa  NaN
# 4       Iris-setosa  NaN
# ..              ...  ...
# 145  Iris-virginica  NaN
# 146  Iris-virginica  NaN
# 147  Iris-virginica  NaN
# 148  Iris-virginica  NaN
# 149  Iris-virginica  NaN
#
# [150 rows x 7 columns]

# %% [markdown]
# ##### 10. Write a Pandas program to add summation to a row of the dataframe.

# %%
### code here
df["summation"]= df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]].sum(axis=1)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  NaN  summation
# 0       Iris-setosa  NaN       10.2
# 1       Iris-setosa  NaN        9.5
# 2       Iris-setosa  NaN        9.4
# 3       Iris-setosa  NaN        9.4
# 4       Iris-setosa  NaN       10.2
# ..              ...  ...        ...
# 145  Iris-virginica  NaN       17.2
# 146  Iris-virginica  NaN       15.7
# 147  Iris-virginica  NaN       16.7
# 148  Iris-virginica  NaN       17.3
# 149  Iris-virginica  NaN       15.8
#
# [150 rows x 8 columns]
