# %% [markdown]
# ######1. load the iris.csv dataset.

# %% [markdown]
# #### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\udayk\LMS_Assignments\1569615-1545342-Data_visualization\Data_visualization\Data_visualization_day_1\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### 1. create a bar plot for count the frequency of the three species.

# %%
### code here
df["Species"].value_counts().plot(kind="bar",figsize=(3,3))
# Out:
# <Axes: xlabel='Species'>

# %% [markdown]
# ##### 2. Create a pie chart to show the percentage of species.

# %%
### code here
df["Species"].value_counts().plot(kind="pie",figsize=(3,3),autopct="%1.1f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 3. Create the joint to all numberical variable for analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
### code here
sns.set(style="whitegrid")
sns.pairplot(df, kind="scatter", diag_kind="kde")

# %% [markdown]
# ##### 4. Create a scatter plot and take hue = "Species"

# %%
### code here
plt.figure(figsize= (6,3))
sns.scatterplot(data=df,x="SepalLengthCm",y="PetalLengthCm",hue="Species")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %% [markdown]
# ###### 5. Create a Boxplot or Whisker plot as univeriate and bivariate analysis.

# %%
### code here
df["SepalLengthCm"].plot(kind="box",figsize=(4,3))
# Out:
# <Axes: >

# %%
plt.figure(figsize= (6,3))
sns.boxplot(data= df,x="SepalLengthCm",y= "Species")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %% [markdown]
# ###### 6. Create a Strip plot

# %%
### code here
plt.figure(figsize= (6,3))
sns.stripplot(data=df,x="SepalLengthCm",y= "Species")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %% [markdown]
# ###### 7. Create a Violin Plot.

# %%
### code here
sns.violinplot(data=df,x="SepalLengthCm",y= "Species")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %% [markdown]
# ##### 8. Create a pair chart.

# %%
### code here
plt.figure(figsize= (3,3))
sns.pairplot(df)

# %% [markdown]
# ##### 9. Create a Heat Map

# %%
### code here
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###### 10. Create a distribution plot for all numerical colomns.

# %%
numeric= df.select_dtypes(exclude="object")

# %%
### code here
sns.set(style="whitegrid")
fig, axes = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(15, 5))

for i, col in enumerate(df.columns):
    sns.histplot(df[col], kde=True, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')
plt.tight_layout()
plt.show()
