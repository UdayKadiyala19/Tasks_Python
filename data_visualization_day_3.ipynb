# %% [markdown]
# ##### import tips dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\udayk\LMS_Assignments\1569615-1545342-Data_visualization\Data_visualization\Data_visualization_day_3\tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
### code here
plt.figure(figsize=(3,3))
sns.barplot(data= df,x= "sex",y= "total_bill")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# Intuition:
# * The total bill of Male are greater than female customers.
# * The total bills of female are slightly lesser than male customers.

# %% [markdown]
# ###### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
#### code here
sns.boxplot(data= df,x= "day",y= "total_bill",hue= "smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Intuition:
# * The boxplot is used to find the outliers and distribution.
# * The outliers are extreme values as in this case,the total bill paid by male,female customers on different days can be treated as values.
# * The outliers can not be replaced because these values are original values as one day Female customers may order more items.

# %% [markdown]
# ##### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here
sns.violinplot(data=df,x="total_bill",y="day",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# Intuition:
# * A violin plot plays a similar role as a box-and-whisker plot. It shows the distribution of data points after grouping by one (or more) variables.

# %% [markdown]
# ##### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here 
sns.stripplot(data=df,x="day",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Intuition:
#
# * Stripplot is similar to scatterplot,but instead of using Cartesian coordinates, they use categorical data along one axis.
# * From the above stripplot,strip represents each day of week.Dots are describing that Male and Female customers unique total_bill.

# %% [markdown]
# ##### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
### code here
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Intuition:
# * Heatmap describes about the correlation between the columns.
# * size,tip both are in weak relation/no relation.
# * size, total_bill and total_bill,tip are in positive moderate relation.

# %% [markdown]
# ##### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
### code here
sns.scatterplot(data=df,x= "total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Intuition:
# * From the scatterplot, the dots are not so much close to regression line.
# * And the dots all are in increasing order so we can say that total_bill is positively moderate with tip.

# %% [markdown]
# ##### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
num= df.select_dtypes(exclude="object")

# %%
### code here
fig, axes = plt.subplots(ncols=len(num.columns), figsize=(15, 5))

for i, col in enumerate(num.columns):
    sns.kdeplot(num[col], ax=axes[i], fill=True)
    axes[i].set_title(f'Density Plot of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# Intuition:
# * From the resulting plots,all the plots are normally distributed because the shape of the curve is bell shape and the mean and median values are closed values.

# %% [markdown]
# ##### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
### code here
df.groupby("day")["total_bill"].mean().plot(kind= "bar",figsize=(4,4))
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# #### Bonus Question

# %% [markdown]
# ###### 1. What is Histogram chart ?

# %% [markdown]
# 1. Histogram chart is continous plot.
# 2. Histogram takes y-label as frequency/occurences of data.
# 3. histogram can be used to find the distribution of the data.

# %% [markdown]
# ##### 2. What is box plot ?

# %% [markdown]
# 1. The main purpose of boxplot is to find the outliers in the data.
# 2. Another use of boxplot is to find the distribution of the data.

# %% [markdown]
# ##### 3. What are the plots we can use for univeriate analysis.

# %% [markdown]
# * If we are dealing with numerical data
#
# -Histogram, Boxplot, Density
#
#
# * If we are dealing with categorical data
#
# -count plot, Bar plot, pie plot

# %% [markdown]
# ##### 4. What are the plots we can use for bivariate analysis.

# %% [markdown]
# 1. Categorical vs categorical
# * crosstab,stacked/group bar,count plot
#
# 2. Categorical vs Numerical
# * Line plot,groupby,pivot table,Bar chart
#
# 3. Numerical vs Numerical
# * scatter plot,correlation

# %% [markdown]
# ###### 5. What are plot we can use for multivariate analysis.

# %% [markdown]
# * For multivariate analysis we can use -pairplot,heatmap
